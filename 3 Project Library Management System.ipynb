# %% [markdown]
# Create a Library Management System
#
# 1. Username Password
# 2. total availables books (math - 0)
# 3. borrow books
# 4. return books
# 5. display borrowed books details along with person's name.
#
# increase and decrease the count of books accordingly.

# %%
username = "SARITA PATRA"
password = "RAKHI123"
totalbooks = {"accountancy":20 , "marketing":10 , "finance":15 , "management":25}
displayed_borrower = {}


print ("WELCOME TO THE NATIONAL DIGITAL LIBRARY OF INDIA")
print ("ENTER YOUR LOGIN DETAILS")
while True:
    user_name =input("enter your user name :")
    if user_name == username:
        pass_word =input("enter your password:")
        if pass_word == password:
            print("login successfully !")
        else:
            print("incorrect password !")
        
    else:print("enter valid username and password")

    while True:

    
        print("available books in the liabrary",totalbooks)
        print("select the option between 1-4")
        print("""
        press 1 for borrow books:
        press 2 for return the books:
        press 3 for display borrower name with borrow books:""")

        choice = int(input("enter your choice"))
        if choice == 1:
            book_name = input("enter your book name:")
            num_book = int(input("enter how many book do you want:"))
            if book_name in totalbooks.keys():
                if num_book <= totalbooks[book_name]:
                    totalbooks[book_name] -= num_book
                else:
                    print("your book is successfully borrowed",book_name,totalbooks[book_name])
                    
                    
            else:
                print("books are not available",book_name)
                print("displayed_borrower")
                print("totalbooks")


        elif choice == 2:
            retbook_name = input("enter your book name:")
            num_book = int(input("enter how many books you return:"))
            if retbook_name in totalbooks.keys():
               totalbooks[retbook_name] +=num_book
            else:
                totalbooks[retbook_name] =num_book
                print("totalbooks")
            
        elif  choice == 3:
            if displayed_borrower =={}:
                print("book not borrowed")
            else:
                for a,b in displayed_borrower.items():
                    print(a,":",b)


else:
    print("incorrect account" )
